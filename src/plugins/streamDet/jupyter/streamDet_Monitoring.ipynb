# %%
import ipywidgets as widgets
from ipywidgets import VBox, HBox, FloatSlider
from streamSubscriber import StreamSubscriber

portTextBox   = widgets.BoundedIntText(value = '5557', min = 5000, max = 6000, step = 1, description = 'Port Number', disabled = False)
nrowsTextBox  = widgets.BoundedIntText(value = '2', min = 1, max = 6, step = 1, description = 'Rows', disabled = False)
ncolsTextBox  = widgets.BoundedIntText(value = '2', min = 1, max = 6, step = 1, description = 'Columns', disabled = False)
threshTextBox = widgets.BoundedIntText(value = '100', min = 0, max = 1024, step = 1, description = 'Hit Threshold', disabled = False)

plotButton = widgets.RadioButtons(options = ['Occupancy', 'Waveform'], description = 'Plot Type', disabled = False)

portTab   = VBox(children = [portTextBox])
threshTab = VBox(children = [threshTextBox])
plotTab   = VBox(children = [plotButton, nrowsTextBox, ncolsTextBox])

tabs = widgets.Tab(children = [portTab, threshTab, plotTab])
tabs.set_title(0, 'Port Selection')
tabs.set_title(1, 'Threshold Selection')
tabs.set_title(2, 'Plot Selection')

tabs
# Out:
# Tab(children=(VBox(children=(BoundedIntText(value=5557, description='Port Number', max=6000, min=5000),)), VBo…

# %%
import matplotlib.pyplot as plt

print ('Port = %d, ADC Threshold = %d, Plot Type = %s' % (portTextBox.value, threshTextBox.value, plotButton.value))

# %matplotlib inline
plt.rcParams['figure.figsize'] = [14.5, 10.5]

if plotButton.value == 'Occupancy':
    StreamSubscriber(plotButton.value, portTextBox.value, threshTextBox.value)
if plotButton.value == 'Waveform':
    StreamSubscriber(plotButton.value, portTextBox.value, threshTextBox.value, nrowsTextBox.value, ncolsTextBox.value)
# Out:
# INDRA Message received -> event = 55, size = 409656 bytes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e278b70eb590> in <module>
#       7
#       8 if plotButton.value == 'Occupancy':
# ----> 9     StreamSubscriber(plotButton.value, portTextBox.value, threshTextBox.value)
#      10 if plotButton.value == 'Waveform':
#      11     StreamSubscriber(plotButton.value, portTextBox.value, threshTextBox.value, nrowsTextBox.value, ncolsTextBox.value)
#
# ~/daq/JANA2/src/plugins/streamDet/jupyter/streamSubscriber.py in __init__(self, plot_type, port, thresh, nrows, ncols)
#      35             self.jana_msg = self.subscriber.recv()
#      36             # instantiate the indra message class
# ---> 37             self.jevent = IndraMessage(self.jana_msg)
#      38             # instantiate the monitoring plot classes
#      39             if self.plot_type == 'Occupancy':
#
# ~/daq/JANA2/src/plugins/streamDet/jupyter/indraMessage.py in __init__(self, zmq_msg)
#      46         for index, sample in np.ndenumerate(self.adc_smpls):
#      47             self.data_dict['adcSamplesChan_%s' % str(index[1] + 1)] = \
# ---> 48                 np.append(self.data_dict['adcSamplesChan_%s' % str(index[1] + 1)], sample)
#      49         # serialize the data dictionary via pickle and publish it
#      50         # self.event_data_dict = pickle.dumps(self.data_dict)
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4696         if arr.ndim != 1:
#    4697             arr = arr.ravel()
# -> 4698         values = ravel(values)
#    4699         axis = arr.ndim-1
#    4700     return concatenate((arr, values), axis=axis)
#
# <__array_function__ internals> in ravel(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in ravel(a, order)
#    1750         return asarray(a).ravel(order=order)
#    1751     else:
# -> 1752         return asanyarray(a).ravel(order=order)
#    1753
#    1754
#
# ~/.local/lib/python3.6/site-packages/numpy/core/_asarray.py in asanyarray(a, dtype, order)
#     136
#     137     """
# --> 138     return array(a, dtype, copy=False, order=order, subok=True)
#     139
#     140
#
# KeyboardInterrupt:
