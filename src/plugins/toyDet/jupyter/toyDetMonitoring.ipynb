# %%
import ipywidgets as widgets
from ipywidgets import VBox, HBox, FloatSlider
from streamSubscriber import StreamSubscriber

portTextBox   = widgets.BoundedIntText(value = '5557', min = 5000, max = 6000, step = 1, description = 'Port Number', disabled = False)
nrowsTextBox  = widgets.BoundedIntText(value = '2', min = 1, max = 6, step = 1, description = 'Rows', disabled = False)
ncolsTextBox  = widgets.BoundedIntText(value = '2', min = 1, max = 6, step = 1, description = 'Columns', disabled = False)
threshTextBox = widgets.BoundedIntText(value = '100', min = 0, max = 1024, step = 1, description = 'Hit Threshold', disabled = False)

portTab   = VBox(children = [portTextBox])
plotTab   = VBox(children = [nrowsTextBox, ncolsTextBox])
threshTab = VBox(children = [threshTextBox])

tabs = widgets.Tab(children = [portTab, plotTab, threshTab])
tabs.set_title(0, 'Port Selection')
tabs.set_title(1, 'Plot Selection')
tabs.set_title(2, 'Threshold Selection')

tabs
# Out:
# Tab(children=(VBox(children=(BoundedIntText(value=5557, description='Port Number', max=6000, min=5000),)), VBo…

# %%
# %matplotlib widget
# StreamSubscriber('occ', portTextBox.value, threshTextBox.value)
StreamSubscriber('wf', portTextBox.value, threshTextBox.value, nrowsTextBox.value, ncolsTextBox.value)
# Out:
# INDRA Message recieved -> event = 54, size = 409656 bytes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-714433056be8> in <module>
#       1 # %matplotlib widget
#       2 # StreamSubscriber('occ', portTextBox.value, threshTextBox.value)
# ----> 3 StreamSubscriber('wf', portTextBox.value, threshTextBox.value, nrowsTextBox.value, ncolsTextBox.value)
#
# ~/daq/JANA2/src/plugins/toyDet/jupyter/streamSubscriber.py in __init__(self, type, port, thresh, nrows, ncols)
#      37             self.janaMessage = self.subscriber.recv()
#      38             # instantiate the indra message class
# ---> 39             self.jevent = IndraMessage(self.janaMessage)
#      40             # instantiate the monitoring plot classes
#      41             if self.plotType == 'occ':
#
# ~/daq/JANA2/src/plugins/toyDet/jupyter/indraMessage.py in __init__(self, zmqMessage)
#      46         for index, sample in np.ndenumerate(self.adcSamples):
#      47             self.dataDict['adcSamplesChan_%s' % str(index[1] + 1)] = \
# ---> 48                 np.append(self.dataDict['adcSamplesChan_%s' % str(index[1] + 1)], sample)
#      49         # serialize the data dictionary via pickle and publish it
#      50         # self.eventDataDict = pickle.dumps(self.dataDict)
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/function_base.py in _append_dispatcher(arr, values, axis)
#    4642
#    4643 def _append_dispatcher(arr, values, axis=None):
# -> 4644     return (arr, values)
#    4645
#    4646
#
# KeyboardInterrupt:

# %% [markdown]
# #
